# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_boston
import warnings
warnings.filterwarnings('ignore')



from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.model_selection import cross_val_score
from scipy.stats import skew
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('data_따릉/2018-2021년_2_자치구별_따릉이_이용건수.csv')
df.drop(columns='Unnamed: 0', inplace=True)

df['일시']=pd.to_datetime(df['일시']) # 날짜형식으로 변경
df['year'] = df.일시.apply(lambda x : x.year)
df['month'] = df.일시.apply(lambda x : x.month)
df['day'] = df.일시.apply(lambda x : x.day)

# %%
test5.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19304\3068802590.py in <module>
# ----> 1 test5.columns
#
# NameError: name 'test5' is not defined

# %%
sns.histplot(df['영등포구'], kde=True) # 정규분포 확인
test5 = df[['평균기온', '최저기온', '최고기온', '일강수량', '최대순간풍속', '최대순간풍속풍향', '최대풍속',
       '최대풍속풍향', '평균풍속', '최다풍향', '평균이슬점온도', '최소상대습도', '평균상대습도', '평균증기압',
       '평균전운량', '평균중하층운량', '일최심적설', '일최심신적설', '강수여부', '일 미세먼지 농도(㎍/㎥)', '휴일여부',
      '요일', '계절', 'year', 'month',
       'day', '영등포구']] #확인할 컬럼 추출

# %%
def get_rmse(model):
    import numpy as np
    from sklearn.metrics import mean_squared_error
    pred = model.predict(X_test)
    mse = mean_squared_error(y_test, pred)
    rmse = np.sqrt(mse)
    print(model.__class__.__name__, 'RMSE: ', np.round(rmse,3))
    print(f'R2: {r2_score(y_test, pred)}')
    return rmse
def get_rmses(models):
    rmses = []
    for model in models:
        rmse = get_rmse(model)
        rmses.append(rmse)
        
    return rmses

# %%
X = test5.drop(columns=['영등포구'])
y = test5['영등포구']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=156)
lr_reg = LinearRegression() #선형회귀
lr_reg.fit(X_train, y_train)
pred = lr_reg.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models) # R2 점수 추가함

# %%
y_train

# %%
# 계산처리 안할거 문자로 바꾸기
test5[[ '강수여부','휴일여부','요일', '계절', 'year', 'month','day',]]= test5[[ '강수여부','휴일여부','요일', '계절', 'year', 'month','day']].astype('str')
# 왜곡도 확인
features_index = test5.dtypes[test5.dtypes != 'object'].index
skew_features= test5[features_index].apply(lambda x : skew(x))
skew_features_top = skew_features[skew_features>1]
skew_features_top.sort_values(ascending=False)
# 왜곡도 1 이상은 로그로 변환
test5[skew_features_top.index]= np.log1p(test5[skew_features_top.index])

# %%
# y값 정규분포로 변환
log_test = np.log1p(test5['영등포구'])

# %%
sns.histplot(test5['영등포구'], kde=True)

# %%
# 문자열 치환 원앤핫인코딩
test5 = pd.get_dummies(test5)
X = test5.drop(columns=['영등포구'])
y = log_test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=156)

# %%
# 모델 확인
lr_reg = LinearRegression()
lr_reg.fit(X_train, np.expm1(y_train))
pred = lr_reg.predict(X_test)
mse = mean_squared_error(np.expm1(y_test), pred)
rmse = np.sqrt(mse)
print(f'lr_reg MSE:  {mse}, RMSE: {rmse}, R2: {r2_score(np.expm1(y_test), pred)}')

ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)
pred =ridge_reg.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print(f'ridge_reg MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')

lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)
pred =lasso_reg.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print(f'lasso_reg MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')

# %%
np.expm1(0.26877252422471865)

# %%
# 루트치환값 다시 원래대로 돌려서 비교
y_t= np.expm1(y_test)
p_t = np.expm1(pred)
for solve, predd in zip(y_t, p_t):
    print(f'{solve}, {predd}')

# %% [markdown]
# # 실제 2022년꺼 예측해보기

# %%
tt18 = df[df['year']==2018]
tt19 = df[df['year']==2019]
tt20 = df[df['year']==2020]
tt21 = df[df['year']==2021]

# %%
 tt21 = tt21[tt21['일시'] < '2021-07-01']

# %%
tt21 = tt21[['month', 'day', '평균기온', '최저기온', '최고기온', '일강수량', '최대순간풍속', '최대순간풍속풍향', '최대풍속',
       '최대풍속풍향', '평균풍속', '최다풍향', '평균이슬점온도', '최소상대습도', '평균상대습도', '평균증기압',
       '평균전운량', '평균중하층운량', '일최심적설', '일최심신적설', '강수여부', '일 미세먼지 농도(㎍/㎥)', '휴일여부',
       '요일', '계절', '영등포구']]

# %%
tt21[[ '강수여부','휴일여부','요일', '계절', 'month','day',]]= tt21[[ '강수여부','휴일여부','요일', '계절', 'month','day']].astype('str')

# %%
tt21d = pd.get_dummies(tt21)

# %%
tt21d.shape

# %%
tt21d.columns
# ['평균기온', '최저기온', '최고기온', '일강수량', '최대순간풍속', '최대순간풍속풍향', '최대풍속', '최대풍속풍향',
#        '평균풍속', '최다풍향', '평균이슬점온도', '최소상대습도', '평균상대습도', '평균증기압', '평균전운량',
#        '평균중하층운량', '일최심적설', '일최심신적설', '일 미세먼지 농도(㎍/㎥)', 'year_2022', 'month_1',
#        'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'day_1',
#        'day_10', 'day_11', 'day_12', 'day_13', 'day_14', 'day_15', 'day_16',
#        'day_17', 'day_18', 'day_19', 'day_2', 'day_20', 'day_21', 'day_22',
#        'day_23', 'day_24', 'day_25', 'day_26', 'day_27', 'day_28', 'day_29',
#        'day_3', 'day_30', 'day_31', 'day_4', 'day_5', 'day_6', 'day_7',
#        'day_8', 'day_9', '강수여부_0.0', '강수여부_1.0', '휴일여부_0', '휴일여부_1', '요일_0',
#        '요일_1', '요일_2', '요일_3', '요일_4', '요일_5', '요일_6', '계절_1', '계절_2', '계절_4']

# %%
X = tt21d.drop(columns=['영등포구'])
y = tt21d['영등포구']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=156)
lr_reg = LinearRegression() #선형회귀
lr_reg.fit(X_train, y_train)
pred = lr_reg.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models) # R2 점수 추가함

# %%
# 모델 확인

pred1 = lr_reg.predict(ttd)
# mse = mean_squared_error(np.expm1(y_test), pred)
# rmse = np.sqrt(mse)
# print(f'lr_reg MSE:  {mse}, RMSE: {rmse}, R2: {r2_score(np.expm1(y_test), pred)}')

pred2 =ridge_reg.predict(ttd)
# mse = mean_squared_error(y_test, pred)
# rmse = np.sqrt(mse)
# print(f'ridge_reg MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')

pred3 =lasso_reg.predict(ttd)
# mse = mean_squared_error(y_test, pred)
# rmse = np.sqrt(mse)
# print(f'lasso_reg MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')

# %%
ttd.drop(columns='year_2022', inplace=True)

# %%
tt21d.columns

# %%
dat= pd.read_csv('답지.csv', index_col=0)

# %%
X_train = tt21d.drop(columns=['영등포구'])
X_test = ttd
y_train = dd
y_test = yy

# %%
dd

# %%
lr_reg.fit(X_train, y_train)
pred = lr_reg.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models) # R2 점수 추가함

# %%
yy= dat['영등포구']

# %%
yy.shape

# %%
pred1.shape

# %%
for solve, predd in zip(yy, pred1):
    print(f'{solve}, {predd}')

# %%
tt20

# %%
tt= pd.read_csv('data_따릉/2022_컬럼_전처리.csv')

# %%
tt.drop(columns='Unnamed: 0', inplace=True)

# %%
tt['일시']= pd.to_datetime(tt['일시'])

# %%
tt = tt[tt['일시'] < '2022-07-01']

# %%
tt['year'] = tt.일시.apply(lambda x : x.year)
tt['month'] = tt.일시.apply(lambda x : x.month)
tt['day'] = tt.일시.apply(lambda x : x.day)

# %%
tt= tt[['year', 'month', 'day', '평균기온', '최저기온', '최고기온', '일강수량', '최대순간풍속', '최대순간풍속풍향', '최대풍속',
       '최대풍속풍향', '평균풍속', '최다풍향', '평균이슬점온도', '최소상대습도', '평균상대습도', '평균증기압',
       '평균전운량', '평균중하층운량', '일최심적설', '일최심신적설', '강수여부', '일 미세먼지 농도(㎍/㎥)', '휴일여부',
       '요일', '계절']]

# %%
tt[[ '강수여부','휴일여부','요일', '계절', 'year', 'month','day',]]= tt[[ '강수여부','휴일여부','요일', '계절', 'year', 'month','day']].astype('str')

# %%
ttd = pd.get_dummies(tt)

# %%
ttd.columns

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(9, 9))
corr = test5.corr()
sns.heatmap(corr, cmap='RdBu', annot=True)

# %%
corr

# %%
fig, axs = plt.subplots(figsize=(16, 8), ncols = 2, nrows = 1)
mv_features = ['계절', '일강수량']
for i, feature in enumerate(mv_features):
    sns.regplot(x=feature, y='영등포구', data = test5, ax = axs[i])

# %% [markdown]
# ## 로지스틱 회귀해보기~

# %%
def get_top_error_data(y_test,pred,n_top=5):
    result_df = pd.DataFrame(y_test.values, columns=['real'])
    result_df['pred']=np.round(pred)
    result_df['diff']= np.abs(result_df['real']- result_df['pred'])
    print(result_df['diff'].mean())
    print(result_df)

# %%
test5

# %%
X = test5.drop(columns=['영등포구'])
y = test5['영등포구']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=156)

# %%
lr_clf = LogisticRegression(solver = 'liblinear')
lr_clf.fit(X_train, y_train)
lr_pred = lr_clf.predict(X_test)
print(accuracy_score(y_test, lr_pred))

# %%
get_top_error_data(y_test,lr_pred)

# %% [markdown]
# ### 랜덤포레스트

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg = RandomForestRegressor(random_state=156, max_depth=8)
rf_reg.fit(X_train, y_train)
pred = rf_reg.predict(X_test)


mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')

# %%
for solve, predd in zip(y_test, pred):
    print(f'{solve}, {predd}')

# %%
# 문자열 치환 원앤핫인코딩
test5 = pd.get_dummies(test5)
X = test5.drop(columns=['영등포구'])
y = log_test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=156)

# %%
rf_reg = RandomForestRegressor(random_state=156, max_depth=8)
rf_reg.fit(X_train, y_train)
pred = rf_reg.predict(X_test)


mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')

# %%
for solve, predd in zip(y_test, pred):
    print(f'{solve}, {predd}')

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
 'max_depth': [16,17,18,19,20],
    'min_samples_split': [1,2,3,4,5],
    'min_samples_leaf':[2,3,4,5,6],
}

# %%
rf_reg = RandomForestRegressor(n_estimators=100,random_state=156, n_jobs= -1)
grid_cv = GridSearchCV(rf_reg, param_grid=params , cv = 2, n_jobs=-1)
grid_cv.fit(X_train, y_train)
pred = grid_cv.predict(X_test)

print(grid_cv.best_params_)
print(grid_cv.best_score_)


mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')

# %%
rf_reg = RandomForestRegressor(n_estimators=500,random_state=156, max_depth=19, min_samples_leaf=2, min_samples_split=2,n_jobs= -1)
rf_reg.fit(X_train, y_train)
pred = rf_reg.predict(X_test)


mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')

# %%
inf = rf_reg.feature_importances_
fff = pd.Series(inf, index = X_train.columns)
ft20 = fff.sort_values(ascending = False)[:20]

sns.barplot(x = ft20, y = ft20.index)
plt.show()

# %%
for solve, predd in zip(np.expm1(y_test), np.expm1(pred)):
    print(f'{solve}, {predd}')

# %% [markdown]
# ### GBM

# %%
from sklearn.ensemble import GradientBoostingRegressor
import time

# %%
# %%time

gb_ref = GradientBoostingRegressor(random_state=156)
gb_ref.fit(X_train, y_train)
gb_pred = gb_ref.predict(X_test)

mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')

# %%
# %%time
grid_cv = GridSearchCV(gb_ref, param_grid=params , cv = 2, n_jobs=-1)
grid_cv.fit(X_train, y_train)
pred = grid_cv.predict(X_test)

print(grid_cv.best_params_)
print(grid_cv.best_score_)

mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')

# %%
gb_ref = GradientBoostingRegressor(n_estimators=200, max_depth=16, min_samples_leaf=6, min_samples_split=2, random_state=156)
gb_ref.fit(X_train, y_train)
gb_pred = gb_ref.predict(X_test)

mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')

# %% [markdown]
# ### LightGBM

# %%
from lightgbm import LGBMRegressor

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=156)
lgbm = LGBMRegressor(n_estimators=100, learning_rate=0.05)

evals = [(X_tr, y_tr), (X_val, y_val)]
lgbm.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric='logloss', eval_set=evals, verbose=True)
preds = lgbm.predict(X_test)

mse = mean_squared_error(y_test, preds)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, preds)}')

# %%
from lightgbm import plot_importance

# %%
fig, ax = plt.subplots(figsize=(10,12))
plot_importance(lgbm, ax=ax)

# %%
for solve, predd in zip(np.expm1(y_test), np.expm1(pred)):
    print(f'{solve}, {predd}')

# %%
from hyperopt import hp

# %%
lgb_space = {
    'max_depth': hp.quniform('max_depth', 5, 20, 1),
    'min_child_weight': hp.quniform('min_child_weight', 1,2,1),
    'learning_rate':hp.uniform('learning_rate',0.01,0.2),
    'colsample_bytree' : hp.uniform('colsample_bytree',0.5,1)
}

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(9, 9))
corr = df.corr()
sns.heatmap(corr, cmap='RdBu', annot=True)
# Out:
# <AxesSubplot:>

# %%
corr_df = df.corr()
s = corr_df.unstack()
df = pd.DataFrame(s[s<1].sort_values(ascending=False), columns=['corr'])
dff = df.style.background_gradient(cmap='viridis')
dff.columns
# Out:
# <style type="text/css">
# #T_587d0_row0_col0, #T_587d0_row1_col0, #T_587d0_row2_col0, #T_587d0_row3_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_587d0_row4_col0, #T_587d0_row5_col0 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_587d0_row6_col0, #T_587d0_row7_col0 {
#   background-color: #f4e61e;
#   color: #000000;
# }
# #T_587d0_row8_col0, #T_587d0_row9_col0 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_587d0_row10_col0, #T_587d0_row11_col0 {
#   background-color: #ece51b;
#   color: #000000;
# }
# #T_587d0_row12_col0, #T_587d0_row13_col0 {
#   background-color: #e5e419;
#   color: #000000;
# }
# #T_587d0_row14_col0, #T_587d0_row15_col0 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_587d0_row16_col0, #T_587d0_row17_col0 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_587d0_row18_col0, #T_587d0_row19_col0 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_587d0_row20_col0, #T_587d0_row21_col0 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_587d0_row22_col0, #T_587d0_row23_col0 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_587d0_row24_col0, #T_587d0_row25_col0, #T_587d0_row26_col0, #T_587d0_row27_col0 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_587d0_row28_col0, #T_587d0_row29_col0 {
#   background-color: #addc30;
#   color: #000000;
# }
# #T_587d0_row30_col0, #T_587d0_row31_col0 {
#   background-color: #9dd93b;
#   color: #000000;
# }
# #T_587d0_row32_col0, #T_587d0_row33_col0 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_587d0_row34_col0, #T_587d0_row35_col0 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_587d0_row36_col0, #T_587d0_row37_col0 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_587d0_row38_col0, #T_587d0_row39_col0 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_587d0_row40_col0, #T_587d0_row41_col0 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_587d0_row42_col0, #T_587d0_row43_col0 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_587d0_row44_col0, #T_587d0_row45_col0 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_587d0_row46_col0, #T_587d0_row47_col0 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_587d0_row48_col0, #T_587d0_row49_col0 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_587d0_row50_col0, #T_587d0_row51_col0 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_587d0_row52_col0, #T_587d0_row53_col0, #T_587d0_row54_col0, #T_587d0_row55_col0 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_587d0_row56_col0, #T_587d0_row57_col0 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_587d0_row58_col0, #T_587d0_row59_col0 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_587d0_row60_col0, #T_587d0_row61_col0 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_587d0_row62_col0, #T_587d0_row63_col0 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_587d0_row64_col0, #T_587d0_row65_col0 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_587d0_row66_col0, #T_587d0_row67_col0, #T_587d0_row68_col0, #T_587d0_row69_col0 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_587d0_row70_col0, #T_587d0_row71_col0 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# #T_587d0_row72_col0, #T_587d0_row73_col0, #T_587d0_row74_col0, #T_587d0_row75_col0 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_587d0_row76_col0, #T_587d0_row77_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_587d0_row78_col0, #T_587d0_row79_col0 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_587d0_row80_col0, #T_587d0_row81_col0, #T_587d0_row82_col0, #T_587d0_row83_col0 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_587d0_row84_col0, #T_587d0_row85_col0, #T_587d0_row86_col0, #T_587d0_row87_col0 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_587d0_row88_col0, #T_587d0_row89_col0 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_587d0_row90_col0, #T_587d0_row91_col0 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_587d0_row92_col0, #T_587d0_row93_col0, #T_587d0_row94_col0, #T_587d0_row95_col0, #T_587d0_row96_col0, #T_587d0_row97_col0 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_587d0_row98_col0, #T_587d0_row99_col0, #T_587d0_row100_col0, #T_587d0_row101_col0 {
#   background-color: #24aa83;
#   color: #f1f1f1;
# }
# #T_587d0_row102_col0, #T_587d0_row103_col0 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_587d0_row104_col0, #T_587d0_row105_col0 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_587d0_row106_col0, #T_587d0_row107_col0, #T_587d0_row108_col0, #T_587d0_row109_col0 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_587d0_row110_col0, #T_587d0_row111_col0 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_587d0_row112_col0, #T_587d0_row113_col0 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_587d0_row114_col0, #T_587d0_row115_col0, #T_587d0_row116_col0, #T_587d0_row117_col0 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_587d0_row118_col0, #T_587d0_row119_col0, #T_587d0_row120_col0, #T_587d0_row121_col0 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_587d0_row122_col0, #T_587d0_row123_col0 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_587d0_row124_col0, #T_587d0_row125_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_587d0_row126_col0, #T_587d0_row127_col0 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_587d0_row128_col0, #T_587d0_row129_col0 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_587d0_row130_col0, #T_587d0_row131_col0, #T_587d0_row132_col0, #T_587d0_row133_col0 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_587d0_row134_col0, #T_587d0_row135_col0, #T_587d0_row136_col0, #T_587d0_row137_col0, #T_587d0_row138_col0, #T_587d0_row139_col0, #T_587d0_row140_col0, #T_587d0_row141_col0, #T_587d0_row142_col0, #T_587d0_row143_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_587d0_row144_col0, #T_587d0_row145_col0 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_587d0_row146_col0, #T_587d0_row147_col0 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_587d0_row148_col0, #T_587d0_row149_col0, #T_587d0_row150_col0, #T_587d0_row151_col0 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_587d0_row152_col0, #T_587d0_row153_col0, #T_587d0_row154_col0, #T_587d0_row155_col0, #T_587d0_row156_col0, #T_587d0_row157_col0 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_587d0_row158_col0, #T_587d0_row159_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_587d0_row160_col0, #T_587d0_row161_col0 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_587d0_row162_col0, #T_587d0_row163_col0, #T_587d0_row164_col0, #T_587d0_row165_col0, #T_587d0_row166_col0, #T_587d0_row167_col0 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_587d0_row168_col0, #T_587d0_row169_col0, #T_587d0_row170_col0, #T_587d0_row171_col0, #T_587d0_row172_col0, #T_587d0_row173_col0 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_587d0_row174_col0, #T_587d0_row175_col0 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_587d0_row176_col0, #T_587d0_row177_col0 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_587d0_row178_col0, #T_587d0_row179_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_587d0_row180_col0, #T_587d0_row181_col0, #T_587d0_row182_col0, #T_587d0_row183_col0, #T_587d0_row184_col0, #T_587d0_row185_col0, #T_587d0_row186_col0, #T_587d0_row187_col0, #T_587d0_row188_col0, #T_587d0_row189_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_587d0_row190_col0, #T_587d0_row191_col0, #T_587d0_row192_col0, #T_587d0_row193_col0, #T_587d0_row194_col0, #T_587d0_row195_col0, #T_587d0_row196_col0, #T_587d0_row197_col0 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_587d0_row198_col0, #T_587d0_row199_col0, #T_587d0_row200_col0, #T_587d0_row201_col0 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_587d0_row202_col0, #T_587d0_row203_col0 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_587d0_row204_col0, #T_587d0_row205_col0, #T_587d0_row206_col0, #T_587d0_row207_col0 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_587d0_r

# %%
# Out:
#                   corr
# 평균기온    최고기온  0.989298
# 최고기온    평균기온  0.989298
# 평균기온    최저기온  0.989262
# 최저기온    평균기온  0.989262
# 평균이슬점온도 최저기온  0.967202
# ...                ...
# 최저기온    계절   -0.497478
# 계절      평균기온 -0.524868
# 평균기온    계절   -0.524868
# 계절      최고기온 -0.544007
# 최고기온    계절   -0.544007
#
# [702 rows x 1 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('data_따릉/영등포구 취합.csv')

# 1. 기온 part
columns = ['평균기온', '최저기온', '최고기온', '평균이슬점온도']
df_temparature = pd.DataFrame(df, columns = columns)
df_temparature['영등포구'] = df['영등포구']
df_temparature

temparature_scaled = StandardScaler().fit_transform(df_temparature.iloc[:,:-1])
temparature_scaled

pca = PCA(n_components = 1)

pca.fit(temparature_scaled)
temparature_pca = pca.transform(temparature_scaled)
temparature_pca.shape

pca_columns = ['기온']
df_temparature_pca = pd.DataFrame(temparature_pca, columns = pca_columns)
df_temparature_pca['영등포구'] = df_temparature['영등포구']
df_temparature_pca,df_temparature

df_temparature_pca

print(pca.explained_variance_ratio_)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
rcf = RandomForestRegressor(random_state=156)
scores = cross_val_score(rcf, df_temparature, df['영등포구'], cv = 3)

print('기온 원본 데이터 교차 검증 개별 정확도:' ,scores)
print('기온 원본 데이터 평균 정확도:' ,np.mean(scores))
# Out:
# 기온 원본 데이터 교차 검증 개별 정확도: [0.99990591 0.99996798 0.95568335]
# 기온 원본 데이터 평균 정확도: 0.9851857491563661

# %%
# 2. 기온 part
columns = ['평균증기압']
df_pressure = pd.DataFrame(df, columns = columns)
df_pressure['영등포구'] = df['영등포구']
df_pressure,df_temparature_pca,df_temparature
# Out:
#       평균증기압    영등포구
# 0       2.1   421.0
# 1       2.2   820.0
# 2       1.8   839.0
# 3       1.8   749.0
# 4       2.4   878.0
# ...     ...     ...
# 1456    2.2  3517.0
# 1457    3.3  4214.0
# 1458    4.6  4126.0
# 1459    2.2  3883.0
# 1460    1.3  3294.0
#
# [1461 rows x 2 columns]

# %%
pressure_scaled = StandardScaler().fit_transform(df_pressure.iloc[:,:-1])
pressure_scaled
# Out:
# array([[-1.15855873],
#        [-1.14648215],
#        [-1.19478849],
#        ...,
#        [-0.85664408],
#        [-1.14648215],
#        [-1.25517142]])

# %%
pca = PCA(n_components = 1)

pca.fit(pressure_scaled)
pressure_pca = pca.transform(pressure_scaled)
pressure_pca.shape
# Out:
# (1461, 1)

# %%
pca_columns = ['기압']
df_pressure_pca = pd.DataFrame(pressure_pca, columns = pca_columns)
df_pressure_pca['영등포구'] = df_pressure['영등포구']
df_pressure_pca
# Out:
#             기압    영등포구
# 0    -1.158559   421.0
# 1    -1.146482   820.0
# 2    -1.194788   839.0
# 3    -1.194788   749.0
# 4    -1.122329   878.0
# ...        ...     ...
# 1456 -1.146482  3517.0
# 1457 -1.013640  4214.0
# 1458 -0.856644  4126.0
# 1459 -1.146482  3883.0
# 1460 -1.255171  3294.0
#
# [1461 rows x 2 columns]

# %%
all = all.merge(df_windspeed_pca, on= '영등포구', axis = 1)
all
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10024\34565817.py in <module>
# ----> 1 all = all.merge(df_windspeed_pca, on= '영등포구', axis = 1)
#       2 all
#
# TypeError: merge() got an unexpected keyword argument 'axis'

# %%
print(pca.explained_variance_ratio_)
# Out:
# [1.]

# %%
rcf = RandomForestRegressor(random_state=156)
scores = cross_val_score(rcf, df_pressure, df['영등포구'], cv = 3)

print('기압 원본 데이터 교차 검증 개별 정확도:' ,scores)
print('기압 원본 데이터 평균 정확도:' ,np.mean(scores))
# Out:
# 기압 원본 데이터 교차 검증 개별 정확도: [0.99992893 0.99997615 0.95695793]
# 기압 원본 데이터 평균 정확도: 0.9856210027178515

# %%
# 3. 풍속 part
columns = ['최대순간풍속','최대풍속']
df_windspeed = pd.DataFrame(df, columns = columns)
df_windspeed['영등포구'] = df['영등포구']
df_windspeed
# Out:
#       최대순간풍속  최대풍속    영등포구
# 0        7.0   3.8   421.0
# 1        8.5   4.9   820.0
# 2        6.6   3.5   839.0
# 3        5.8   3.5   749.0
# 4        8.0   3.6   878.0
# ...      ...   ...     ...
# 1456     5.5   3.1  3517.0
# 1457     4.9   3.1  4214.0
# 1458    10.8   5.9  4126.0
# 1459    12.3   6.6  3883.0
# 1460    11.9   5.4  3294.0
#
# [1461 rows x 3 columns]

# %%
windspeed_scaled = StandardScaler().fit_transform(df_windspeed.iloc[:,:-1])
windspeed_scaled
# Out:
# array([[-0.51623692, -0.53648561],
#        [ 0.09635416,  0.3353781 ],
#        [-0.67959455, -0.77426662],
#        ...,
#        [ 1.0356605 ,  1.12798147],
#        [ 1.64825158,  1.68280383],
#        [ 1.48489396,  0.73167978]])

# %%
pca = PCA(n_components = 1)

pca.fit(windspeed_scaled)
windspeed_pca = pca.transform(windspeed_scaled)
windspeed_pca.shape
# Out:
# (1461, 1)

# %%
pca_columns = ['풍속']
df_windspeed_pca = pd.DataFrame(windspeed_pca, columns = pca_columns)
df_windspeed_pca['영등포구'] = df_windspeed['영등포구']
df_windspeed_pca
# Out:
#             풍속    영등포구
# 0    -0.744387   421.0
# 1     0.305281   820.0
# 2    -1.028035   839.0
# 3    -1.259058   749.0
# 4    -0.567700   878.0
# ...        ...     ...
# 1456 -1.569873  3517.0
# 1457 -1.743140  4214.0
# 1458  1.529926  4126.0
# 1459  2.355412  3883.0
# 1460  1.567354  3294.0
#
# [1461 rows x 2 columns]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.9583097]

# %%
rcf = RandomForestRegressor(random_state=156)
scores = cross_val_score(rcf, df_windspeed, df['영등포구'], cv = 3)

print('풍속 원본 데이터 교차 검증 개별 정확도:' ,scores)
print('풍속 원본 데이터 평균 정확도:' ,np.mean(scores))
# Out:
# 풍속 원본 데이터 교차 검증 개별 정확도: [0.99991991 0.99997589 0.95287859]
# 풍속 원본 데이터 평균 정확도: 0.9842581287169491

# %%
# 4. 습도 part
columns = ['최소상대습도','평균상대습도']
df_humidity = pd.DataFrame(df, columns = columns)
df_humidity['영등포구'] = df['영등포구']
df_humidity
# Out:
#       최소상대습도  평균상대습도    영등포구
# 0         19    39.1   421.0
# 1         19    42.0   820.0
# 2         28    42.3   839.0
# 3         31    43.0   749.0
# 4         32    48.4   878.0
# ...      ...     ...     ...
# 1456      38    60.9  3517.0
# 1457      57    73.8  4214.0
# 1458      50    72.9  4126.0
# 1459      34    48.5  3883.0
# 1460      26    35.9  3294.0
#
# [1461 rows x 3 columns]

# %%
humidity_scaled = StandardScaler().fit_transform(df_humidity.iloc[:,:-1])
humidity_scaled
# Out:
# array([[-1.24418947, -1.40942252],
#        [-1.24418947, -1.22079997],
#        [-0.70132222, -1.2012873 ],
#        ...,
#        [ 0.6256866 ,  0.78900576],
#        [-0.33941073, -0.7980253 ],
#        [-0.82195939, -1.61755774]])

# %%
pca = PCA(n_components = 1)

pca.fit(humidity_scaled)
humidity_pca = pca.transform(humidity_scaled)
humidity_pca.shape
# Out:
# (1461, 1)

# %%
pca_columns = ['습도']
df_humidity_pca = pd.DataFrame(humidity_pca, columns = pca_columns)
df_humidity_pca['영등포구'] = df_humidity['영등포구']
df_humidity_pca
# Out:
#             습도    영등포구
# 0    -1.876387   421.0
# 1    -1.743011   820.0
# 2    -1.345348   839.0
# 3    -1.185199   749.0
# 4    -0.894191   878.0
# ...        ...     ...
# 1456 -0.063383  3517.0
# 1457  1.340293  4214.0
# 1458  1.000339  4126.0
# 1459 -0.804289  3883.0
# 1460 -1.724999  3294.0
#
# [1461 rows x 2 columns]

# %%
all = all.merge(df_humidity_pca, on= '영등포구')

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.95237324]

# %%
rcf = RandomForestRegressor(random_state=156)
scores = cross_val_score(rcf, df_humidity, df['영등포구'], cv = 3)

print('습도 원본 데이터 교차 검증 개별 정확도:' ,scores)
print('습도 원본 데이터 평균 정확도:' ,np.mean(scores))
# Out:
# 습도 원본 데이터 교차 검증 개별 정확도: [0.99989414 0.99997506 0.95549589]
# 습도 원본 데이터 평균 정확도: 0.9851216943505762

# %%
# 5. 운량 part
columns = ['평균전운량','평균중하층운량']
df_cloud = pd.DataFrame(df, columns = columns)
df_cloud['영등포구'] = df['영등포구']
df_cloud
# Out:
#       평균전운량  평균중하층운량    영등포구
# 0       1.0      0.9   421.0
# 1       2.3      0.0   820.0
# 2       3.6      0.0   839.0
# 3       6.5      2.9   749.0
# 4       3.6      0.8   878.0
# ...     ...      ...     ...
# 1456    3.1      3.1  3517.0
# 1457    4.1      4.1  4214.0
# 1458    5.1      5.1  4126.0
# 1459    2.0      1.9  3883.0
# 1460    0.0      0.0  3294.0
#
# [1461 rows x 3 columns]

# %%
cloud_scaled = StandardScaler().fit_transform(df_cloud.iloc[:,:-1])
cloud_scaled
# Out:
# array([[-1.26916724, -0.83941291],
#        [-0.846475  , -1.18691748],
#        [-0.42378275, -1.18691748],
#        ...,
#        [ 0.06393907,  0.78227511],
#        [-0.94401936, -0.45329671],
#        [-1.59431513, -1.18691748]])

# %%
pca = PCA(n_components = 1)

pca.fit(humidity_scaled)
cloud_pca = pca.transform(cloud_scaled)
cloud_pca.shape
# Out:
# (1461, 1)

# %%
pca_columns = ['운량']
df_humidity_pca = pd.DataFrame(humidity_pca, columns = pca_columns)
df_humidity_pca['영등포구'] = df_humidity['영등포구']
df_humidity_pca
# Out:
#             운량    영등포구
# 0    -1.876387   421.0
# 1    -1.743011   820.0
# 2    -1.345348   839.0
# 3    -1.185199   749.0
# 4    -0.894191   878.0
# ...        ...     ...
# 1456 -0.063383  3517.0
# 1457  1.340293  4214.0
# 1458  1.000339  4126.0
# 1459 -0.804289  3883.0
# 1460 -1.724999  3294.0
#
# [1461 rows x 2 columns]

# %%
all = all.merge(df_humidity_pca, on= '영등포구')

# %%
all
# Out:
#             기온    영등포구        기압      풍속_x      풍속_y        운량
# 0     2.849341   421.0 -1.158559 -0.744387 -0.744387 -1.876387
# 1     2.938423   820.0 -1.146482  0.305281  0.305281 -1.743011
# 2     3.383496   839.0 -1.194788 -1.028035 -1.028035 -1.345348
# 3     3.464808   749.0 -1.194788 -1.259058 -1.259058 -1.185199
# 4     3.001599   878.0 -1.122329 -0.567700 -0.567700 -0.894191
# ...        ...     ...       ...       ...       ...       ...
# 6046  4.719180  1129.0 -1.279325  0.393624  0.393624 -1.162203
# 6047  3.133569  4214.0 -1.013640 -1.743140 -1.743140  1.340293
# 6048  2.202502  4126.0 -0.856644  1.529926  1.529926  1.000339
# 6049  3.200306  3883.0 -1.146482  2.355412  2.355412 -0.804289
# 6050  3.876458  3294.0 -1.255171  1.567354  1.567354 -1.724999
#
# [6051 rows x 6 columns]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.95237324]

# %%
rcf = RandomForestRegressor(random_state=156)
scores = cross_val_score(rcf, df_cloud, df['영등포구'], cv = 3)

print('운량 원본 데이터 교차 검증 개별 정확도:' ,scores)
print('운량 원본 데이터 평균 정확도:' ,np.mean(scores))
# Out:
# 운량 원본 데이터 교차 검증 개별 정확도: [0.99991528 0.99997744 0.95602125]
# 운량 원본 데이터 평균 정확도: 0.9853046557423909

# %%
all = all.merge(test5, on= '영등포구')

# %%
all.drop(columns='풍속_y', inplace=True)

# %%
all.columns = ['기온', '영등포구', '기압', '풍속', '운량']

# %%
all.columns
# Out:
# Index(['기온', '영등포구', '기압', '풍속', '운량', '평균기온', '최저기온', '최고기온', '일강수량',
#        '최대순간풍속', '최대순간풍속풍향', '최대풍속', '최대풍속풍향', '평균풍속', '최다풍향', '평균이슬점온도',
#        '최소상대습도', '평균상대습도', '평균증기압', '평균전운량', '평균중하층운량', '일최심적설', '일최심신적설',
#        '강수여부', '일 미세먼지 농도(㎍/㎥)', '휴일여부', '요일', '계절', 'year', 'month', 'day'],
#       dtype='object')

# %%
all.drop(columns=['평균기온', '최저기온', '최고기온','평균이슬점온도','평균증기압','최대순간풍속','최대풍속','최소상대습도', '평균상대습도', '평균전운량', '평균중하층운량'], inplace=True)

# %%
all.to_csv('최종_데이터.csv', index=False)

# %%
test5.head(50)
# Out:
#     평균기온  최저기온  최고기온  일강수량  최대순간풍속  최대순간풍속풍향  최대풍속  최대풍속풍향  평균풍속  최다풍향  ...  \
# 0   -1.3  -5.1   3.8   0.0     7.0       320   3.8     290   1.4   290  ...
# 1   -1.8  -4.3   1.8   0.0     8.5       270   4.9     290   1.8   290  ...
# 2   -4.7  -7.1  -0.4   0.0     6.6       320   3.5     270   2.2   290  ...
# 3   -4.7  -8.7  -0.7   0.0     5.8       320   3.5     320   1.4   290  ...
# 4   -3.0  -5.6   1.6   0.0     8.0       250   3.6     270   1.7   290  ...
# 5   -2.8  -6.8   2.9   0.0     5.9       290   3.1     290   1.5   290  ...
# 6   -0.8  -5.7   2.8   0.0     5.5       110   2.5     160   0.8    90  ...
# 7    1.3  -1.2   4.0   0.9    11.5       270   7.1     290   1.8   270  ...
# 8   -4.2  -6.1  -1.2   0.5    11.0       290   6.1     270   2.9   290  ...
# 9   -7.5 -10.3  -4.8   0.3    11.7       320   6.1     320   3.0   290  ...
# 10 -11.1 -13.6  -7.4   0.0     9.2       290   4.9     320   2.8   290  ...
# 11 -10.2 -15.3  -5.4   0.0     6.4       270   3.6     320   1.7   290  ...
# 12  -4.4  -6.6  -1.2   0.4     4.2        20   1.7     290   0.8    50  ...
# 13   0.6  -4.4   5.4   0.0     5.3        90   2.8     160   1.2    90  ...
# 14   4.7   1.8   7.7   0.2     7.7       320   3.3     340   1.4   290  ...
# 15   3.5   0.1   6.8   0.0     4.4        20   2.2     200   0.7    20  ...
# 16   4.5   2.4   8.7   0.0     6.9       250   3.7     290   1.2   290  ...
# 17   2.1   0.3   4.5   0.0     6.4       290   3.8     290   1.9   290  ...
# 18   1.0  -2.5   5.5   0.0     7.6       270   3.7     320   1.6   290  ...
# 19   2.2  -1.0   6.9   0.0     6.8       340   3.6     290   1.6   270  ...
# 20   0.4  -3.7   5.5   0.0     5.2       180   3.2     290   1.0   290  ...
# 21   0.2  -5.3   4.0   3.3     9.3       320   5.1     320   1.5   290  ...
# 22 -11.7 -14.6  -5.3   0.0    10.5       360   5.4     290   3.7   290  ...
# 23 -14.2 -16.3 -10.7   0.0    12.0       360   7.2     320   3.4   290  ...
# 24 -14.0 -16.4  -9.5   0.0     9.5       320   4.8     290   2.8   340  ...
# 25 -14.8 -17.8 -10.7   0.0     7.9       320   4.6     320   2.6   320  ...
# 26  -9.9 -15.9  -3.5   0.0     5.8       180   3.4     270   1.4   270  ...
# 27  -6.3  -9.3  -1.2   0.0    10.3       320   5.6     320   2.6   290  ...
# 28  -8.5 -11.6  -4.7   0.0    12.2       290   6.2     320   2.7   270  ...
# 29  -5.3 -11.4  -0.8   2.9     7.9       270   3.8     230   1.3   200  ...
# 30  -2.6  -5.2   0.0   0.0     6.1       290   3.4     340   1.6   290  ...
# 31  -4.0  -8.8   1.2   0.0     6.7       290   3.9     320   1.6   290  ...
# 32  -2.4  -7.6   3.8   0.0     6.6       270   3.6     270   1.6   290  ...
# 33  -7.3 -10.4  -2.1   0.5    10.5       320   5.7     320   3.8   290  ...
# 34  -9.5 -12.8  -5.2   0.0     9.6       320   5.6     320   3.1   290  ...
# 35  -9.4 -11.8  -5.1   0.0    10.1       320   5.6     320   3.0   290  ...
# 36 -10.1 -12.8  -5.8   0.0    10.0       340   4.9     290   3.1   290  ...
# 37  -8.0 -13.4  -1.6   0.0     6.9       320   3.3     270   1.5   290  ...
# 38  -4.4  -9.7   2.0   0.0     5.8       290   3.0     270   1.2    20  ...
# 39   0.4  -5.3   6.1   0.0     5.9       250   3.0     250   1.1   230  ...
# 40  -0.5  -6.9   3.2   0.0    11.4       290   6.3     320   3.0   290  ...
# 41  -6.1  -9.5  -2.2   0.0     9.3       270   5.1     290   2.7   270  ...
# 42  -5.8  -9.6  -1.8   0.0    10.6       180   5.2     290   2.7   270  ...
# 43  -0.8  -7.4   4.3   0.0    12.2       230   5.6     250   2.7   200  ...
# 44   3.5  -0.7   8.7   0.0    10.0       200   5.4     320   2.6   250  ...
# 45  -0.7  -3.7   4.0   0.0     7.9       270   4.4     320   2.5   290  ...
# 46  -1.1  -5.5   4.9   0.0     9.7       250   5.5     320   2.1   270  ...
# 47  -3.0  -7.1   1.4   0.0    11.0       250   5.5     290   2.9   290  ...
# 48  -0.4  -4.9   5.2   0.0     6.2       290   3.5     270   1.3   270  ...
# 49   1.8  -1.9   6.8   0.0     5.5       270   3.0     290   1.5   290  ...
#
#     일최심신적설  강수여부  일 미세먼지 농도(㎍/㎥)  휴일여부  요일  계절  year  month  day   영등포구
# 0      0.0   0.0            38.0     1   0   4  2018      1    1  421.0
# 1      0.0   0.0            32.0     0   1   4  2018      1    2  820.0
# 2      0.0   0.0            32.0     0   2   4  2018      1    3  839.0
# 3      0.0   0.0            40.0     0   3   4  2018      1    4  749.0
# 4      0.0   0.0            46.0     0   4   4  2018      1    5  878.0
# 5      0.0   0.0            40.0     0   5   4  2018      1    6  479.0
# 6      0.0   0.0            42.0     0   6   4  2018      1    7  396.0
# 7      1.0   1.0            41.0     0   0   4  2018      1    8  696.0
# 8      0.5   1.0            35.0     0   1   4  2018      1    9  699.0
# 9      0.3   1.0            26.0     0   2   4  2018      1   10  505.0
# 10     0.0   0.0            29.0     0   3   4  2018      1   11  483.0
# 11     0.0   0.0            24.0     0   4   4  2018      1   12  520.0
# 12     0.6   1.0            44.0     0   5   4  2018      1   13  326.0
# 13     0.0   0.0            52.0     0   6   4  2018      1   14  418.0
# 14     0.0   1.0            56.0     0   0   4  2018      1   15  837.0
# 15     0.0   0.0            87.0     0   1   4  2018      1   16  846.0
# 16     0.0   0.0            80.0     0   2   4  2018      1   17  802.0
# 17     0.0   0.0            67.0     0   3   4  2018      1   18  765.0
# 18     0.0   0.0            50.0     0   4   4  2018      1   19  892.0
# 19     0.0   0.0            86.0     0   5   4  2018      1   20  508.0
# 20     0.0   0.0            53.0     0   6   4  2018      1   21  435.0
# 21     1.0   1.0            34.0     0   0   4  2018      1   22  571.0
# 22     0.0   0.0            19.0     0   1   4  2018      1   23  494.0
# 23     0.0   0.0            28.0     0   2   4  2018      1   24  387.0
# 24     0.0   0.0            24.0     0   3   4  2018      1   25  382.0
# 25     0.0   0.0            30.0     0   4   4  2018      1   26  353.0
# 26     0.0   0.0            38.0     0   5   4  2018      1   27  203.0
# 27     0.0   0.0            26.0     0   6   4  2018      1   28  244.0
# 28     0.0   0.0            42.0     0   0   4  2018      1   29  512.0
# 29     3.5   1.0            39.0     0   1   4  2018      1   30  410.0
# 30     0.0   0.0            35.0     0   2   4  2018      1   31  450.0
# 31     0.0   0.0            34.0     0   3   4  2018      2    1  632.0
# 32     0.0   0.0            43.0     0   4   4  2018      2    2  753.0
# 33     0.3   1.0            28.0     0   5   4  2018      2    3  271.0
# 34     0.0   0.0            31.0     0   6   4  2018      2    4  207.0
# 35     0.0   0.0            24.0     0   0   4  2018      2    5  481.0
# 36     0.0   0.0            28.0     0   1   4  2018      2    6  464.0
# 37     0.0   0.0            36.0     0   2   4  2018      2    7  520.0
# 38     0.0   0.0            42.0     0   3   4  2018      2    8  709.0
# 39     0.0   0.0            51.0     0   4   4  2018      2    9  802.0
# 40     0.0   0.0            55.0     0   5   4  2018      2   10  413.0
# 41     0.0   0.0            48.0     0   6   4  2018      2   11  216.0
# 42     0.0   0.0            45.0     0   0   4  2018      2   12  624.0
# 43     0.0   0.0            46.0     0   1   4  2018      2   13  750.0
# 44     0.0   0.0            56.0     0   2   4  2018      2   14  867.0
# 45     0.0   0.0            35.0     1   3   4  2018      2   15  310.0
# 46     0.0   0.0            38.0     1   4   4  2018      2   16  235.0
# 47     0.0   0.0            45.0     1   5   4  2018      2   17  262.0
# 48     0.0   0.0            35.0     0   6   4  2018      2   18  460.0
# 49     0.0   0.0            50.0     0   0   4  2018      2   19  985.0
#
# [50 rows x 27 columns]

# %%
df_temparature_pca
df_pressure_pca
df_windspeed_pca
df_humidity_pca
df_humidity_pca

# %%
all = pd.concat([df_temparature_pca,
df_pressure_pca,
df_windspeed_pca,
df_humidity_pca], axis=1)

# %%
all = all[['기온',  '기압',  '풍속', '운량1']]

# %%
all.columns = ['기온', '기압', '풍속', '운량']

# %%
fin = pd.concat([test5,all], axis = 1)

# %%
fin.columns
# Out:
# Index(['일강수량', '최대순간풍속풍향', '최대풍속풍향', '평균풍속', '최다풍향', '일최심적설', '일최심신적설', '강수여부',
#        '일 미세먼지 농도(㎍/㎥)', '휴일여부', '요일', '계절', 'year', 'month', 'day', '영등포구',
#        '기온', '기압', '풍속', '운량'],
#       dtype='object')

# %%
fin.drop(columns=['평균기온', '최저기온', '최고기온','평균이슬점온도','평균증기압','최대순간풍속','최대풍속','최소상대습도', '평균상대습도', '평균전운량', '평균중하층운량'], inplace=True)

# %%
fin = fin[['기온', '기압', '풍속', '운량','일강수량', '최대순간풍속풍향', '최대풍속풍향', '평균풍속', '최다풍향', '일최심적설', '일최심신적설', '강수여부',
       '일 미세먼지 농도(㎍/㎥)', '휴일여부', '요일', '계절', 'year', 'month', 'day', '영등포구',
       ]]

# %%
fin.to_csv('최최종.csv', index=False)
